# %% [markdown]
# ## beautiful soup

# %%
from bs4 import BeautifulSoup, NavigableString
import requests
import pandas as pd

# %%
url = 'https://www.tfrrs.org/results/xc/25186/Panorama_Farms_Invitational'

# %%
page = requests.get(url) #send a get request to the url, will return a response object

# %%
#204, 400, 404 are all bad request responses

# %%
soup = BeautifulSoup(page.text, 'html') #page is sending the request and .text is retrieving the raw HTML that we're going to use

# %%
print(soup.prettify()) #adds indentations - makes it look a little better
# Out:
# <!DOCTYPE html>
# <html class="no-js js-menubar" lang="en">
#  <head>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-0Z9Z2N6ZD0">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-0Z9Z2N6ZD0');
#   </script>
#   <!-- Google Analytics -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-66287-6', 'auto');
# ga('send', 'pageview');
#   </script>
#   <!-- End Google Analytics -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimal-ui" name="viewport"/>
#   <meta content="" name="author"/>
#   <title>
#    TFRRS | Panorama Farms Invitational - Meet Results
#   </title>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="-rpUYNNTDrWbHF4w2r_Fbu7iZZh9YTOmjy5TvcqBZBMP5l9sbP2t0zT3i_3q8VsLKyf2ZBzS2wfM3zDu8ZHItA" name="csrf-token"/>
#   <link data-turbo-track="reload" href="/assets/application-a1113638bc156e6e214c8f9c53207d764d24305a643c770eec0a2eebfd1b4f8e.css" rel="stylesheet"/>
#   <script data-turbo-track="reload" defer="defer" src="/assets/application-d4008ddeb261f22a9f53f3dddd43752869320b84c550fd43799c92ffa08750df.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/jquery.min-3e889c340ba9f9e88ff5f1badaeaceec65dd060a0232a85eb144c9b62b2786fe.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/typeahead.bundle.min-d18d792426fa7f0a9679ed2c33e71307a8fe09561df9f593465a4d6feba70aec.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/tablesaw.jquery.min-4701cd748c6834f95c3161b48f459469158169ddf7c12219be1c12c34481dd59.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/tablesaw-init.min-1d6a00c96918bd12190e2fb280b0f5517d523937ed1845e65f13c4ab26130352.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/jquery.tablesorter.min-fe520a3599ba9fc81844e8160254f452265de294151587c5dc8389022a0c404a.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/widget-filter.min-1d2e9572bc5b838def30b532beaadf466ec4a4232e1a5a29088cccc092fe3086.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/jquery-asScrollbar.min-c9765e34bfd33c5bc144253cdfccb3f2347afc9c3c92a8c8adf041183bc8913e.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/jquery-asScrollable.min-581394978134953074cf3346996ad52e1d43ce9255c4c6ea05975833b502b8d0.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/breakpoints-c357bc89f972ec2735029b3c3bc86bd4d54625b8347d4347ab57a1fdff2b027b.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/babel-external-helpers-3bb9d34dcbba0de2bc460fb97b17cb78345d4df3873425d88dab40ff8c29b93e.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/tether.min-1ca7b7364b258390c80bd1394bc5f3eda891b8c0b012b8ef26e03a9d369616ca.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/popper.min-a35160b48a83891e024ad0e561f6d718eb47b9da1e8c8591f564894d30e49453.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/bootstrap.min-b7e4b4eb09e42019e53eb11387a89ad1e4a7ca09a3b705c43db6167a5f4f37fa.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/State-22323558f7bdfbe6ee1fe771491a431bbdd0206669a8804bd9d7ed2340563e85.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/Component-d3b4189b709f8f5f34cda43509ddc3c24c69e13aa07fdcd150eb6de5a5e5567c.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/Plugin-c667fcb4a45c3b7fe8291856a03f82025b733501885d532ed91ddaf9899c37d5.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/Base-fdda45b3789c693e7e36db949b8455a47ad123039e8e1c80873d29f6196c6017.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/Menubar-ca18355478b4182b2c6fd46e39e576692fb46ebb338e3697af3294be001dc091.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/Sidebar-2b8a4fb8775cad5c8f48b4e9072c520a128c93de44277a03f356ffccd442f049.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/PageAside-9e225775b27ecd8847c282f548f820399a4d261977a154d240f4d042dbc2264c.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/menu-92ed59eeb67da3f42ee4a3919171b2cce1b94d01d0e781f427979eab697c30b9.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/AssetSite-820c527b2f05e216e7844316f29636d287a82e7622a8312b28ed7da37413ec28.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/bootstrap-datepicker.min-f3fcc2903d76b2cdb29452b3f0256c90772fd3beeb7818be185aaa4db6362a0a.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/bootstrap-select.min-281407c5f68d119b06e38b696397e1d8139e5fe6052bb203b9b7e545059035d7.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/init-2e09e52e809bcfa5e2219133005caefc381babaf24f41ad12cb56fb58adf3711.js">
#   </script>
#   <link data-turbo-track="reload" href="/assets/bootstrap.min-ea362e84a9f5cc626295a685aca36b51950bedfa00454f5eb8ae1f2454484a2f.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/bootstrap-extend.min-e818edbc82dcdb6c8a15c7b7830852f21184d7014b58337689186b7b03528bca.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/site-58a6a8df1b1f345f7102340bcec41da64ef5209b33e8d662b2fe47830220de20.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/main-19d90a676b47e99838610a8cdd53f709fe0abffc40cd0e72567547f3f3b99de2.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/tablesaw-9aadb8b0a807a577c968d42d977f70b89acbca55dfba8784138576dd9f14587f.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/asScrollable-bf8159f60730f7391f091c5807a2c0f1e0ddbae2c3708dc87a8dd2125ef27829.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/typeahead.min-ca8d2708c2f18195741f87b0e469a4e99688b7fb67bc179553e089863af5d550.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/Roboto-23a1c1e33751bd43df85d705836b96b590f2f13a491e7687c932835aa0b069d1.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/proxima-nova-46208f674a9effe7c048ac37d6c7ef4f356e45f975c293696e48c65ee327fded.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/font-awesome-ce93c9293a2ef156c2930be8f14768ebfb33d213bf3159eb0c982eb201e1f3b0.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/material-design.min-7954ef339aa441ba58fdeba9c480b4e44b7a276f423568a58c6ecfa2f1306c57.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/frame-support-9304d5b0bd8d10156c6ba27255a589b0583833ed622210120063cdc471ed8fae.css" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/bootstrap-select.min-b248e59e991ebc495c96bdfce4c677452becca97820ea670a23d508a82a52adf.css" rel="stylesheet"/>
#   <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#   <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="//assets.tfrrs.org/images/favicons/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
#   <link href="//assets.tfrrs.org/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="//assets.tfrrs.org/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="//assets.tfrrs.org/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="//assets.tfrrs.org/images/favicons/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/>
#   <meta content=" " name="application-name"/>
#   <meta content="#FFFFFF" name="msapplication-TileColor"/>
#   <meta content="//assets.tfrrs.org/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="//assets.tfrrs.org/images/favicons/mstile-70x70.png" name="msapplication-square70x70logo"/>
#   <meta content="//assets.tfrrs.org/images/favicons/mstile-150x150.png" name="msapplication-square150x150logo"/>
#   <meta content="//assets.tfrrs.org/images/favicons/mstile-310x150.png" name="msapplication-wide310x150logo"/>
#   <meta content="//assets.tfrrs.org/images/favicons/mstile-310x310.png" name="msapplication-square310x310logo"/>
#   <style>
#    ::-webkit-scrollbar {
#     width:9px;
# }
#
# ::-webkit-scrollbar-track {
#     -webkit-border-radius:5px;
#     border-radius:5px;
#     background:rgba(0,0,0,0.1);
# }
#
# ::-webkit-scrollbar-thumb {
#     -webkit-border-radius:5px;
#     border-radius:5px;
#     background:rgba(0,0,0,0.2);
# }
#
# ::-webkit-scrollbar-thumb:hover {
#     background:rgba(0,0,0,0.4);
# }
#
# ::-webkit-scrollbar-thumb:window-inactive {
#     background:rgba(0,0,0,0.05);
# }
#
# #scrollable-dropdown-menu .tt-menu {
#   max-height: 150px;
#   overflow-y: scroll;
# }
#
# .no-scrollbar::-webkit-scrollbar {
#   display: none;
# }
#
# .hoka-navbar-brand-logo {
#     height: 40px !important;
# }
#
# img.hoka-navbar-brand-logo {
#     display: inline-block;
#     vertical-align: top;
# }
#   </style>
#   <script async="" src="https://99bad415-a15a-4792-bd4c-dd79f2848ebb.redfastlabs.com/assets/redfast.js">
#   </script>
#  </head>
#  <body class="page-body" style="background-image: url('//assets.tfrrs.org/images/da_xc_bg.jpg') ;">
#   <nav class="site-navbar navbar navbar-default navbar-mega hidden-lg-up hidden-md-up" role="navigation">
#    <div class="container">
#     <div class="navbar-header">
#      <div class="navbar-brand">
#       <a class="navbar-brand-logo" href="//www.tfrrs.org">
#        <img class="navbar-brand-logo" src="//assets.tfrrs.org/images/TFRRS_XC_157x30.png" title="TFRRS-XC LOGO"/>
#       </a>
#       <span style="font-size:27px;color:gray;position:relative; top:10px;">
#        /
#       </span>
#       <img class="hoka-navbar-brand-logo" src="//assets.tfrrs.org/sponsor/hoka/hoka_blue.png" title="HOKA Logo"/>
#      </div>
#     </div>
#    </div>
#   </nav>
#   <div class="site-menu-mobile">
#    <button class="navbar-toggler hamburger hamburger-close navbar-toggler-left hided" data-toggle="menubar" type="button">
#     <span class="sr-only">
#      Toggle navigation
#     </span>
#     <span class="hamburger-bar">
#     </span>
#    </button>
#   </div>
#   <div class="site-menubar">
#    <div class="site-menubar-body container">
#     <div>
#      <div>
#       <div class="inline-block site-menu-logo">
#        <a href="//www.tfrrs.org">
#         <img class="mb-15 w-200" src="//assets.tfrrs.org/images/TFRRS_XC_200x38.png" title=""/>
#        </a>
#        <span style="font-size:36px;vertical-align: bottom;">
#         /
#        </span>
#        <img height="58px" src="//assets.tfrrs.org/sponsor/hoka/hoka_blue.png" title="HOKA Logo"/>
#       </div>
#       <ul class="site-menu inline-block ml-lg-40" data-plugin="menu">
#        <li class="site-menu-item has-sub">
#         <a class="waves-effect waves-classic" dropdown-badge="false" style="color:#4c4654">
#          <span class="">
#           TEAMS
#          </span>
#          <i aria-hidden="true" class="site-menu-arrow fa fa-chevron-down mt-10">
#          </i>
#         </a>
#         <ul class="site-menu-sub">
#          <li class="site-menu-item">
#           <div class="input-group m-20 w-250 hidden-sm-down">
#            <div id="scrollable-dropdown-menu">
#             <input class="form-control" id="team_search" name="team_search" onkeypress="teamKeyPress(event)" placeholder="Search for a team..." type="text"/>
#            </div>
#            <span class="input-group-btn">
#             <div class="btn btn-primary" onclick="teamsSubmit()">
#              <i aria-hidden="true" class="fa fa-search">
#              </i>
#             </div>
#            </span>
#           </div>
#           <div class="input-search clearfix hidden-lg-up hidden-md-up input-search-menu">
#            <button class="input-search-btn" type="submit">
#             <i aria-hidden="true" class="fa fa-search">
#             </i>
#            </button>
#            <div id="scrollable-dropdown-menu">
#             <input class="form-control" id="mobile_team_search" name="mobile_team_search" placeholder="Search Teams" type="text"/>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </li>
#        <li class="site-menu-item has-sub">
#         <a class="waves-effect waves-classic" dropdown-badge="false" style="color:#4c4654">
#          <span class="">
#           CONFERENCES
#          </span>
#          <i aria-hidden="true" class="site-menu-arrow fa fa-chevron-down mt-10">
#          </i>
#         </a>
#         <ul class="site-menu-sub">
#          <li class="site-menu-item">
#           <div class="input-group m-20 w-250 hidden-sm-down" id="scrollable-dropdown-menu">
#            <input class="form-control" id="conference_search" name="conference_search" onkeypress="conferenceKeyPress(event)" placeholder="Search for a conference..." type="text"/>
#            <span class="input-group-btn">
#             <div class="btn btn-primary" onclick="conferenceSubmit();">
#              <i aria-hidden="true" class="fa fa-search">
#              </i>
#             </div>
#            </span>
#           </div>
#           <div class="input-search clearfix hidden-lg-up hidden-md-up input-search-menu">
#            <button class="input-search-btn" type="submit">
#             <i aria-hidden="true" class="fa fa-search">
#             </i>
#            </button>
#            <div id="scrollable-dropdown-menu">
#             <input class="form-control" id="mobile_conference_search" name="mobile_conference_search" placeholder="Search Conferences" type="text"/>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </li>
#        <li class="site-menu-item">
#         <a class="waves-effect waves-classic" dropdown-badge="false" href="https://www.tfrrs.org/results_search.html">
#          <span class="">
#           RESULTS
#          </span>
#         </a>
#        </li>
#        <li class="site-menu-item has-sub hidden-sm-down">
#         <a class="waves-effect waves-classic" dropdown-badge="false" style="color:#4c4654">
#          <span class="">
#           LISTS
#          </span>
#          <i aria-hidden="true" class="site-menu-arrow fa fa-chevron-down">
#          </i>
#         </a>
#         <ul class="site-menu-sub">
#          <li class="site-menu-item">
#           <a class="animsition-link waves-effect waves-classic" href="https://tf.tfrrs.org/indoor_lists.html">
#            <span class="site-menu-title">
#             INDOOR LISTS
#            </span>
#           </a>
#          </li>
#          <li class="site-menu-item">
#           <a class="animsition-link waves-effect waves-classic" href="https://tf.tfrrs.org/outdoor_lists.html">
#            <span class="site-menu-title">
#             OUTDOOR LISTS
#            </span>
#           </a>
#          </li>
#          <li class="site-menu-item">
#           <a class="animsition-link waves-effect waves-classic" href="https://tf.tfrrs.org/archives.html">
#            <span class="site-menu-title">
#             ARCHIVES
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="site-menu-item hidden-md-up hidden-lg-up hidden-xl-up">
#         <a class="waves-effect waves-classic" dropdown-badge="false" href="https://tf.tfrrs.org/indoor_lists.html">
#          <span>
#           INDOOR LISTS
#          </span>
#         </a>
#        </li>
#        <li class="site-menu-item hidden-md-up hidden-lg-up hidden-xl-up">
#         <a class="waves-effect waves-classic" dropdown-badge="false" href="https://tf.tfrrs.org/outdoor_lists.html">
#          <span>
#           OUTDOOR LISTS
#          </span>
#         </a>
#        </li>
#        <li class="site-menu-item hidden-md-up hidden-lg-up hidden-xl-up">
#         <a class="animsition-link waves-effect waves-classic" href="https://tf.tfrrs.org/archives.html">
#          <span>
#           ARCHIVES
#          </span>
#         </a>
#        </li>
#        <turbo-frame class="inline-block float-right" id="login_nav" src="/loginNavigation.html">
#        </turbo-frame>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <style>
#    a.anchor{display: block; position: relative; top: -80px; visibility: hidden;}
#   </style>
#   <script>
#    function navigateTo(sel, target, newWindow) {
#   var url = sel.options[sel.selectedIndex].value;
#   if (newWindow) {
#     window.open(url, target, '--- attributes here, see below ---');
#   } else {
#     window[target].location.href = url;
#   }
#   }
#   </script>
#   <div class="page container">
#    <div class="page-content panel-container">
#     <div class="panel panel-bordered">
#      <div class="panel-heading xc-heading">
#       <h3 class="panel-title">
#        Panorama Farms Invitational
#       </h3>
#      </div>
#      <div class="panel-second-title">
#       <div class="row xc-header-row">
#        <div class="col-lg-8">
#         <div>
#          <div>
#           <div class="panel-heading-normal-text inline-block">
#            October 19, 2024
#           </div>
#           <span class="panel-heading-normal-text hidden-xs-down hidden-sm-down">
#            |
#           </span>
#           <div class="clearfix hidden-md-up">
#           </div>
#           <div class="panel-heading-normal-text inline-block">
#            Panorama Farms
#
#
#
#                     Earlysville, VA 22936
#           </div>
#          </div>
#          <span class="panel-heading-text" style="white-space: nowrap;">
#           HOST: Virginia
#          </span>
#          <span class="panel-heading-text" style="white-space: nowrap;">
#           DIRECTOR: Carter Olander
#          </span>
#          <span class="panel-heading-text" style="white-space: nowrap;">
#           TIMING: Flash Results, Inc.
#          </span>
#          <span class="panel-heading-text" style="white-space: nowrap;">
#           REFEREE: Greg Roth
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-lg-12">
#         <label class="event-links">
#          LIST OF EVENTS:
#         </label>
#         <ol class="inline-list pl-0 pt-5 events-list" id="quick-links-list">
#          <li>
#           <a href="#event161144">
#            Women 6k CC
#           </a>
#          </li>
#          <li>
#           <a href="#event161145">
#            Men 8k CC
#           </a>
#          </li>
#         </ol>
#         <select class="form-control hidden-div" id="quick-links-select" name="events_links" onchange="navigateTo(this, 'window', false);">
#          <option value="#event161144">
#           Women 6k CC
#          </option>
#          <option value="#event161145">
#           Men 8k CC
#          </option>
#         </select>
#        </div>
#       </div>
#      </div>
#      <div class="panel-body">
#       <a class="anchor" name="event161144">
#       </a>
#       <div class="row">
#        <div class="col-lg-12">
#         <div class="custom-table-title custom-table-title-xc">
#          <h3 class="font-weight-500">
#           Women 6k CC Team Results
#       (6k)
#           <span class="top-anchor">
#            <a href="#top">
#             <h5>
#              Top↑
#             </h5>
#            </a>
#           </span>
#          </h3>
#         </div>
#         <table class="tablesaw tablesaw-xc table-striped table-bordered table-hover" data-tablesaw-mode="columntoggle">
#          <thead>
#           <tr>
#            <th data-tablesaw-priority="persist" scope="col">
#             PL
#            </th>
#            <th data-tablesaw-priority="persist" scope="col">
#             Team
#            </th>
#            <th data-tablesaw-priority="2" scope="col">
#             Total Time
#            </th>
#            <th data-tablesaw-priority="2" scope="col">
#             Avg. Time
#            </th>
#            <th data-tablesaw-priority="persist" scope="col">
#             Score
#            </th>
#            <th data-tablesaw-priority="3" scope="col">
#             1
#            </th>
#            <th data-tablesaw-priority="4" scope="col">
#             2
#            </th>
#            <th data-tablesaw-priority="5" scope="col">
#             3
#            </th>
#            <th data-tablesaw-priority="6" scope="col">
#             4
#            </th>
#            <th data-tablesaw-priority="6" scope="col">
#             5
#            </th>
#            <th data-tablesaw-priority="6" scope="col">
#             6
#            </th>
#            <th data-tablesaw-priority="6" scope="col">
#             7
#            </th>
#           </tr>
#          </thead>
#          <tbody class="color-xc">
#           <tr>
#            <td>
#             1
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virginia.html">
#              Virginia
#             </a>
#            </td>
#            <td>
#             1:42:50
#            </td>
#            <td>
#             20:34
#            </td>
#            <td id="team_score_56">
#             17
#            </td>
#            <td>
#             1
#            </td>
#            <td>
#             2
#            </td>
#            <td>
#             3
#            </td>
#            <td>
#             4
#            </td>
#            <td>
#             7
#            </td>
#            <td>
#             8
#            </td>
#            <td>
#             20
#            </td>
#           </tr>
#           <tr>
#            <td>
#             2
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virgin
#             NAME
#            </th>
#            <th data-tablesaw-priority="2" scope="col">
#             YEAR
#            </th>
#            <th data-tablesaw-priority="persist" scope="col">
#             TEAM
#            </th>
#            <th data-tablesaw-priority="3" scope="col">
#             Avg. Mile
#            </th>
#            <th data-tablesaw-priority="1" scope="col">
#             TIME
#            </th>
#            <th data-tablesaw-priority="persist" scope="col">
#             SCORE
#            </th>
#           </tr>
#          </thead>
#          <tbody class="color-xc">
#           <tr>
#            <td>
#             1
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8622078/Virginia/Jenny__Schilling.html">
#              Jenny  Schilling
#             </a>
#            </td>
#            <td>
#             JR-3
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virginia.html">
#              Virginia
#             </a>
#            </td>
#            <td>
#             05:24.4
#            </td>
#            <td>
#             20:09.7
#            </td>
#            <td>
#             1
#            </td>
#           </tr>
#           <tr>
#            <td>
#             2
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/7897038/Virginia/Sophie_Atkinson.html">
#              Sophie Atkinson
#             </a>
#            </td>
#            <td>
#             SR-4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virginia.html">
#              Virginia
#             </a>
#            </td>
#            <td>
#             05:29.3
#            </td>
#            <td>
#             20:27.9
#            </td>
#            <td>
#             2
#            </td>
#           </tr>
#           <tr>
#            <td>
#             3
#            </td>
#            <td>
#             Jette Beermann
#            </td>
#            <td>
#             ?
#            </td>
#            <td>
#             Unattached
#            </td>
#            <td>
#             05:29.5
#            </td>
#            <td>
#             20:28.7
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8622080/Virginia/Tatum_David.html">
#              Tatum David
#             </a>
#            </td>
#            <td>
#             SO-2
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virginia.html">
#              Virginia
#             </a>
#            </td>
#            <td>
#             05:32.1
#            </td>
#            <td>
#             20:38.2
#            </td>
#            <td>
#             3
#            </td>
#           </tr>
#           <tr>
#            <td>
#             5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8256305/Virginia/Camryn_Menninger.html">
#              Camryn Menninger
#             </a>
#            </td>
#            <td>
#             SR-4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virginia.html">
#              Virginia
#             </a>
#            </td>
#            <td>
#             05:33.8
#            </td>
#            <td>
#             20:44.5
#            </td>
#            <td>
#             4
#            </td>
#           </tr>
#           <tr>
#            <td>
#             6
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8242109/High_Point/Charli__Montalvo.html">
#              Charli  Montalvo
#             </a>
#            </td>
#            <td>
#             JR-3
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/NC_college_f_High_Point.html">
#              High Point
#             </a>
#            </td>
#            <td>
#             05:35.0
#            </td>
#            <td>
#             20:48.9
#            </td>
#            <td>
#             5
#            </td>
#           </tr>
#           <tr>
#            <td>
#             7
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/7699722/Coastal_Carolina/Molly__Jones.html">
#              Molly  Jones
#             </a>
#            </td>
#            <td>
#             SR-4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/SC_college_f_Coastal_Carolina.html">
#              Coastal Carolina
#             </a>
#            </td>
#            <td>
#             05:35.2
#            </td>
#            <td>
#             20:49.6
#            </td>
#            <td>
#             6
#            </td>
#           </tr>
#           <tr>
#            <td>
#             8
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8622074/Virginia/Cate_DeSousa.html">
#              Cate DeSousa
#             </a>
#            </td>
#            <td>
#             SO-2
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virginia.html">
#              Virginia
#             </a>
#            </td>
#            <td>
#             05:35.4
#            </td>
#            <td>
#             20:50.5
#            </td>
#            <td>
#             7
#            </td>
#           </tr>
#           <tr>
#            <td>
#             9
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8924282/Virginia/Sarah_Peer.html">
#              Sarah Peer
#             </a>
#            </td>
#            <td>
#             FR-1
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virginia.html">
#              Virginia
#             </a>
#            </td>
#            <td>
#             05:35.4
#            </td>
#            <td>
#             20:50.6
#            </td>
#            <td>
#             8
#            </td>
#           </tr>
#           <tr>
#            <td>
#             10
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8720154/Virginia_Tech/Sharon_Chepchirchir.html">
#              Sharon Chepchirchir
#             </a>
#            </td>
#            <td>
#             FR-1
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virginia_Tech.html">
#              Virginia Tech
#             </a>
#            </td>
#            <td>
#             05:36.2
#            </td>
#            <td>
#             20:53.6
#            </td>
#            <td>
#             9
#            </td>
#           </tr>
#           <tr>
#            <td>
#             11
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8936382/Virginia_Tech/Katie_Bohlke.html">
#              Katie Bohlke
#             </a>
#            </td>
#            <td>
#             FR-1
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_f_Virgin
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/7908352/Coastal_Carolina/Tomas_Duncan.html">
#              Tomas Duncan
#             </a>
#            </td>
#            <td>
#             SR-4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/SC_college_m_Coastal_Carolina.html">
#              Coastal Carolina
#             </a>
#            </td>
#            <td>
#            </td>
#            <td>
#             DNF
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             0
#            </td>
#            <td>
#             Alex Valencia
#            </td>
#            <td>
#             ?
#            </td>
#            <td>
#             Unattached
#            </td>
#            <td>
#            </td>
#            <td>
#             DNF
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             0
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/athletes/8621223/Virginia/Matthew_Fernando.html">
#              Matthew Fernando
#             </a>
#            </td>
#            <td>
#             SO-2
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="https://www.tfrrs.org/teams/xc/VA_college_m_Virginia.html">
#              Virginia
#             </a>
#            </td>
#            <td>
#            </td>
#            <td>
#             DNF
#            </td>
#            <td>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer class="site-footer">
#    <div class="container vertical-container">
#     <div class="site-footer-center">
#      <div class="footer-terms text-center">
#       <a href="https://www.tfrrs.org/privacy.html">
#        PRIVACY
#       </a>
#       <span>
#        /
#       </span>
#       <a href="https://www.tfrrs.org/tos.html">
#        TERMS OF USE
#       </a>
#       <span>
#        /
#       </span>
#       <a href="https://www.tfrrs.org/sites.html">
#        SITES
#       </a>
#       <span>
#        /
#       </span>
#       <a href="//www.tfrrs.org/director_info.html">
#        SUBMITTING RESULTS
#       </a>
#       <span>
#        /
#       </span>
#       <a href="mailto:info@tfrrs.org">
#        CONTACT TFRRS
#       </a>
#      </div>
#      <div id="autoComplete" style="display:none">
#      </div>
#      <p class="footer-text text-center hidden-xs-down hidden-sm-down">
#       TRACK &amp; FIELD RESULTS REPORTING SYSTEM
#      </p>
#      <div class="text-center">
#       <a href="https://www.directathletics.com">
#        <img class="footer-logo" src="//assets.tfrrs.org/images/footer-logo.jpg"/>
#       </a>
#       <a href="https://tf.tfrrs.org/">
#        <img class="footer-logo-xc" src="//assets.tfrrs.org/images/tfrrs_logo.jpg"/>
#       </a>
#       <a href="https://florida.tfrrs.org/">
#        <img class="footer-logo-xc" src="//assets.tfrrs.org/images/TFRRS_FL_cropped.png" style="padding-top:20px"/>
#       </a>
#      </div>
#      <p class="text-center footer-copyright">
#       Copyright © 2024 DirectAthletics, Inc.
#      </p>
#      <div class="text-center footer-copyright" style="font-size:8px">
#       Generated 2024-10-26 06:44:11
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script>
#    var substringMatcher = function(strs) {
#   return function findMatches(q, cb) {
#     var matches, substringRegex;
#
#     // an array that will be populated with substring matches
#     matches = [];
#
#     // regex used to determine if a string contains the substring `q`
#     substrRegex = new RegExp(q, 'i');
#
#     // iterate through the pool of strings and for any string that
#     // contains the substring `q`, add it to the `matches` array
#     $.each(strs, function(i, str) {
#       if (substrRegex.test(str)) {
#         matches.push(str);
#       }
#     });
#
#     cb(matches);
#   };
# };
#
# var autoCompleteMatcher = function(strs) {
#   return function findMatches(q, cb) {
#     var matches, substringRegex;
#
#     // an array that will be populated with substring matches
#     matches = [];
#     var search = q.split('(')[0];
#     // regex used to determine if a string contains the substring `q`
#     substrRegex = new RegExp(search, 'i');
#
#     // iterate through the pool of strings and for any string that
#     // contains the substring `q`, add it to the `matches` array
#     $.each(strs, function(i, str) {
#       if (substrRegex.test(str.text)) {
#         matches.push(str);
#       }
#     });
#
#     cb(matches);
#   };
# };
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/assets/list_autocomplete-4a8d0c670d77d7485e4b3faa528b7d74241c5941a93c508a1a789c5a486593f5.js">
#   </script>
#   <script data-turbo-track="reload" defer="defer" src="/js/navbar_autocomplete.js">
#   </script>
#   <link href="//assets.tfrrs.org/css/bootstrap-datepicker3.standalone.min.css" rel="stylesheet"/>
#  </body>
# </html>

# %% [markdown]
# ## find and find_all

# %%
table = soup.find_all('table')[1]

# %%
world_titles = table.find_all('th')

# %%
world_titles #this is a list, each col name is within the <th> tag
# Out:
# [<th data-tablesaw-priority="persist" scope="col">PL
#          </th>,
#  <th data-tablesaw-priority="persist" scope="col">NAME
#          </th>,
#  <th data-tablesaw-priority="2" scope="col">YEAR
#          </th>,
#  <th data-tablesaw-priority="persist" scope="col">TEAM
#          </th>,
#  <th data-tablesaw-priority="3" scope="col">Avg. Mile
#          </th>,
#  <th data-tablesaw-priority="1" scope="col">TIME
#          </th>,
#  <th data-tablesaw-priority="persist" scope="col">SCORE
#          </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]
print(world_table_titles)
# Out:
# ['PL', 'NAME', 'YEAR', 'TEAM', 'Avg. Mile', 'TIME', 'SCORE']

# %% [markdown]
# ### put it into a pandas dataframe

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [PL, NAME, YEAR, TEAM, Avg. Mile, TIME, SCORE]
# Index: []

# %% [markdown]
# ### trying to add course name/year to dataframe:

# %%
df = pd.DataFrame(columns = world_table_titles + ['COURSE','YEAR'])
df
# Out:
# Empty DataFrame
# Columns: [PL, NAME, YEAR, TEAM, Avg. Mile, TIME, SCORE, COURSE, YEAR]
# Index: []

# %% [markdown]
# ### keep going

# %%
#actual rows of results (names with times and such)
column_data = table.find_all('tr')

# %%
#name of course
course_div = soup.find('div', class_ = 'panel-heading xc-heading')
course_name = course_div.find('h3').text.strip()

# %%
#year 
year_div = soup.find('div', class_ = 'panel-heading-normal-text inline-block')
year = year_div.text.strip()

# %%
#looping through column_data (stuff with <tr> tag) to find <td> tag
num_columns = len(df.columns)
for row in column_data[1:]: 
    if hasattr(row, 'find_all'):
        row_data = row.find_all('td') #individual (row) data
        individual_row_data = [data.text.strip() for data in row_data] #getting and stripping text for each row
        
        individual_row_data.append(course_name)
        individual_row_data.append(year)
            
        #current data frame:
        length = len(df)
        df.loc[length] = individual_row_data #appending each row of the information into the next position

# %%
df
# Out:
#     PL              NAME  YEAR              TEAM Avg. Mile     TIME SCORE  \
# 0    1  Jenny  Schilling  JR-3          Virginia   05:24.4  20:09.7     1
# 1    2   Sophie Atkinson  SR-4          Virginia   05:29.3  20:27.9     2
# 2    3    Jette Beermann     ?        Unattached   05:29.5  20:28.7
# 3    4       Tatum David  SO-2          Virginia   05:32.1  20:38.2     3
# 4    5  Camryn Menninger  SR-4          Virginia   05:33.8  20:44.5     4
# ..  ..               ...   ...               ...       ...      ...   ...
# 134  0  Charlotte Hudson  FR-1          Richmond                DNF
# 135  0       Iris Downes  SO-2              Duke                DNF
# 136  0    Katelyn Porter  SO-2  Coastal Carolina                DNF
# 137  0        Star Price  JR-3     Virginia Tech                DNF
# 138  0    Amelia Maughan     ?        Unattached                DNF
#
#                           COURSE              YEAR
# 0    Panorama Farms Invitational  October 19, 2024
# 1    Panorama Farms Invitational  October 19, 2024
# 2    Panorama Farms Invitational  October 19, 2024
# 3    Panorama Farms Invitational  October 19, 2024
# 4    Panorama Farms Invitational  October 19, 2024
# ..                           ...               ...
# 134  Panorama Farms Invitational  October 19, 2024
# 135  Panorama Farms Invitational  October 19, 2024
# 136  Panorama Farms Invitational  October 19, 2024
# 137  Panorama Farms Invitational  October 19, 2024
# 138  Panorama Farms Invitational  October 19, 2024
#
# [139 rows x 9 columns]

# %% [markdown]
# ## making it a function

# %%
def get_results(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html')
    
    table = soup.find_all('table')[1]
    
    world_titles = table.find_all('th')
    world_table_titles = [title.text.strip() for title in world_titles]
    
    df = pd.DataFrame(columns = world_table_titles + ['COURSE', 'YEAR'])
    
    #course_div = soup.find('div', class_ = 'panel-heading xc-heading')
    #course_name = course_div.fine('h3').text.strip()
    
    #year_div = soup.find('div', class_ = 'panel-heading-normal-text inline block')
    #year = year_div.text.strip()
    
    column_data = table.find_all('tr')
    
    for row in column_data[1:]:
        if hasattr(row, 'find_all'):
            row_data = row.find_all('td')
            individual_row_data = [data.text.strip() for data in row_data]
            
            individual_row_data.append(course_name)
            individual_row_data.append(year)
            
            length = len(df)
            df.loc[length] = individual_row_data
            
    return df

# %%
get_results("https://www.tfrrs.org/results/xc/23362/2024_Pirate_Cross_Country_Invitational_")
# Out:
#       PL               NAME  YEAR                 TEAM Avg. Mile     TIME  \
# 0      1   Peninah  Mutisya  FR-1              Hampton   05:36.4  20:54.4
# 1      2       Kyra Holland  SR-4       William & Mary   05:39.8  21:07.1
# 2      3      Sofia Istnick  JR-3       William & Mary   05:47.5  21:35.8
# 3      4     Arianna DeBoer  SR-4       William & Mary   05:48.5  21:39.3
# 4      5    Sarah McCartney  SR-4  Charleston Southern   05:49.3  21:42.4
# ..   ...                ...   ...                  ...       ...      ...
# 204  205  Abigail Snodgrass  SO-2         George Mason   07:25.8  27:42.2
# 205  206    Harrison Grooms  SR-4             Davidson   07:26.4  27:44.4
# 206  207      Winter Oaster  FR-1                 Elon   07:29.6  27:56.2
# 207  208       Caitlin Peck  JR-3                 UNCW   07:49.0  29:08.9
# 208  209   Isabelle Johnson  JR-3             Milligan   07:58.4  29:43.8
#
#     SCORE                       COURSE              YEAR
# 0          Panorama Farms Invitational  October 19, 2024
# 1       1  Panorama Farms Invitational  October 19, 2024
# 2       2  Panorama Farms Invitational  October 19, 2024
# 3       3  Panorama Farms Invitational  October 19, 2024
# 4       4  Panorama Farms Invitational  October 19, 2024
# ..    ...                          ...               ...
# 204        Panorama Farms Invitational  October 19, 2024
# 205        Panorama Farms Invitational  October 19, 2024
# 206        Panorama Farms Invitational  October 19, 2024
# 207   138  Panorama Farms Invitational  October 19, 2024
# 208        Panorama Farms Invitational  October 19, 2024
#
# [209 rows x 9 columns]
